# %%
import pandas as pd

INSEE_PATH = "INSEE/"
file_name = "DS_RP_POPULATION_PRINC_2022_data.csv"

df = pd.read_csv(INSEE_PATH + file_name, sep=";")
df.head()
# Out:
# /tmp/ipykernel_30379/994562613.py:6: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(INSEE_PATH + file_name, sep=";")
#       AGE    GEO GEO_OBJECT RP_MEASURE SEX  TIME_PERIOD  OBS_VALUE
# 0  Y_GE80  88244        COM        POP  _T         2022  34.527109
# 1  Y_GE80  43111        COM        POP  _T         2022  70.793678
# 2  Y_LT15  36205        COM        POP  _T         2022   8.643833
# 3  Y65T79  85286        COM        POP  _T         2022  83.169815
# 4  Y65T79  34303        COM        POP  _T         2022  18.000000

# %%
import requests

url = "https://api.insee.fr/melodi/data/DS_RP_POPULATION_PRINC"

response = requests.get(url)
data = response.json()

print(data)
